# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (1.2.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.33.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.9.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.0.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (7.34.1)
# Requirement already satisfied: websockets>=13.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: pycparser in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf
import pandas as pd

stock = yf.download(
    "AAPL",  #Ticker symbol
    period="7d",
    interval="1h"
)

stock.reset_index(inplace=True)

stock.to_csv(
    "stock_data_fresh.csv",
    index=False
)

stock.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                   Datetime       Close        High         Low  \
# Ticker                                  AAPL        AAPL        AAPL
# 0      2026-05-28 13:30:00+00:00  311.700012  312.760010  309.600006
# 1      2026-05-28 14:30:00+00:00  311.825012  311.970001  311.049988
# 2      2026-05-28 15:30:00+00:00  310.440002  311.945007  310.307495
# 3      2026-05-28 16:30:00+00:00  310.799988  311.619995  309.570007
# 4      2026-05-28 17:30:00+00:00  310.839996  311.019989  310.109985
#
# Price         Open   Volume
# Ticker        AAPL     AAPL
# 0       310.679993  7569372
# 1       311.700012  3612059
# 2       311.825012  3704416
# 3       310.445007  3879761
# 4       310.815002  3474234

# %%
stock["Datetime"].min() #To ensure all datasets cover the same analysis period.
# Out:
# Timestamp('2026-05-28 13:30:00+0000', tz='UTC')

# %%
stock["Datetime"].max()
# Out:
# Timestamp('2026-06-05 19:30:00+0000', tz='UTC')

# %%
import requests

url = (
    "https://newsapi.org/v2/everything?"
    "q=Apple&"
    "sortBy=publishedAt&"
    "language=en&"
    "pageSize=100&"
    "apiKey=ec430183bc9f43968b1ef3f5cbbacb12"
)

response = requests.get(url)

data = response.json()

articles = []

for article in data ["articles"]:
    articles.append([
        article["title"],
        article["publishedAt"],
        article["source"]["name"]
            ])

news_df = pd.DataFrame(
    articles,
    columns=[
        "title",
        "publishedAt",
        "source"
    ])

news_df.to_csv(
    "news_data_fresh.csv",
    index=False
)

news_df.head()
# Out:
#                                                title           publishedAt  \
# 0  Rebecca Lowe: America is going to ‘fall in lov...  2026-06-06T20:45:01Z
# 1  Bayern Munich star Lennart Karl could be out s...  2026-06-06T20:36:01Z
# 2  Fastest mobile chipsets ranked: compare smartp...  2026-06-06T20:33:02Z
# 3                  pymcu-avr-toolchain added to PyPI  2026-06-06T20:07:10Z
# 4  Groveton Centerville baseball shuts out Gordon...  2026-06-06T20:03:32Z
#
#                     source
# 0         Awful Announcing
# 1  Bavarian Football Works
# 2             GSMArena.com
# 3                 Pypi.org
# 4                 Ketk.com

# %%
news_df["publishedAt"].min()
# Out:
# '2026-06-06T14:30:00Z'

# %%
news_df["publishedAt"].max()
# Out:
# '2026-06-06T20:45:01Z'

# %%
#To align the stock dataset with the news dataset and ensure both datasets covered the same analysis period. We used filter

# %%
stock["Datetime"] = pd.to_datetime(stock["Datetime"])

filtered_stock = stock[
    stock["Datetime"]>="2026-06-04"
    ]
filtered_stock.head()
# Out:
# Price                   Datetime       Close        High         Low  \
# Ticker                                  AAPL        AAPL        AAPL
# 35     2026-06-04 13:30:00+00:00  310.250000  313.540009  309.900085
# 36     2026-06-04 14:30:00+00:00  310.399994  311.350006  309.799988
# 37     2026-06-04 15:30:00+00:00  310.630005  311.109985  309.649994
# 38     2026-06-04 16:30:00+00:00  311.665009  311.790009  310.480011
# 39     2026-06-04 17:30:00+00:00  311.420013  311.975006  310.989990
#
# Price         Open   Volume
# Ticker        AAPL     AAPL
# 35      313.304993  9640009
# 36      310.260010  3601740
# 37      310.410004  3102831
# 38      310.630005  3514607
# 39      311.670013  2206917

# %%
filtered_stock["Datetime"].min()
# Out:
# Timestamp('2026-06-04 13:30:00+0000', tz='UTC')

# %%
filtered_stock["Datetime"].max()
# Out:
# Timestamp('2026-06-05 19:30:00+0000', tz='UTC')

# %%
#I used financial market data and real-time news to analyze how sentiment impacts stock movement.

# %%
news_df=pd.read_csv("news_data.csv")
stock_df=pd.read_csv("stock_data.csv")

# %%
news_df["time"] = pd.to_datetime(news_df["time"])

# %%
print(news_df["time"].head())
# Out:
# 0   2026-05-11 17:57:56+00:00
# 1   2026-05-13 03:20:23+00:00
# 2   2026-04-22 22:05:10+00:00
# 3   2026-05-05 21:19:26+00:00
# 4   2026-04-22 15:32:28+00:00
# Name: time, dtype: datetime64[ns, UTC]

# %%
#CLEAN NEWS DATA
news_df.columns
# Out:
# Index(['title', 'time'], dtype='object')

# %%
#Remove Nulls
news_df.dropna(inplace=True)

# %%
#Remove Duplicates
news_df.drop_duplicates(inplace=True)

# %%
import re
def clean_text(text):
    text=text.lower()  #lowercase
    text = re.sub(r"http\S+", "", text)  # remove links
    text = re.sub(r"[^a-zA-Z ]", "", text)  # remove symbols
    return text

news_df["clean_title"] = news_df["title"].apply(clean_text)

# %%
#CLEAN STOCK DATA
stock_df.columns
# Out:
# Index(['Price', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
#Reset Index
stock_df.reset_index(inplace=True)

# %%
#Rename Columns
stock_df.rename(columns={"index": "time"}, inplace=True)

# %%
stock_df.columns
# Out:
# Index(['time', 'Price', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
#Select Important Columns
stock_df = stock_df[["time","Open","Close"]]

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (9.6.0)
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password = "root",
    database = "market_analysis"
)

cursor = conn.cursor()

#Insert news
for i, row in news_df.iterrows():
    cursor.execute(
        "INSERT INTO news (title, clean_title) VALUES (%s, %s)",
        (row["title"], row["clean_title"])
    )
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Unknown column 'title' in 'field list'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[18], line 13
#       9 cursor = conn.cursor()
#      10
#      11 #Insert news
#      12 for i, row in news_df.iterrows():
# ---> 13     cursor.execute(
#      14         "INSERT INTO news (title, clean_title) VALUES (%s, %s)",
#      15         (row["title"], row["clean_title"])
#      16     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\cursor_cext.py:353, in CMySQLCursor.execute(self, operation, params, map_results)
#     345 self._executed = (
#     346     self._stmt_partition["single_stmts"].popleft()
#     347     if map_results
#     348     else self._stmt_partition["mappable_stmt"]
#     349 )
#     351 try:
#     352     self._handle_result(
# --> 353         self._connection.cmd_query(
#     354             self._stmt_partition["mappable_stmt"],
#     355             raw=self._raw,
#     356             buffered=self._buffered,
#     357             raw_as_string=self._raw_as_string,
#     358         )
#     359     )
#     360 except MySQLInterfaceError as err:
#     361     if hasattr(err, "errno"):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:781, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     779 except MySQLInterfaceError as err:
#     780     if hasattr(err, "errno"):
# --> 781         raise get_mysql_exception(
#     782             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     783         ) from err
#     784     raise InterfaceError(str(err)) from err
#     785 except AttributeError as err:
#
# ProgrammingError: 1054 (42S22): Unknown column 'title' in 'field list'

# %%
'''“I performed data profiling and cleaning using Python,
handled duplicates and nulls, and structured the data into a MySQL database for further analysis.”'''

# %%
#Save the cleaned News data

news_df.to_csv("cleaned_news_data.csv", index=False)

# %%
news_df=pd.read_csv("cleaned_news_data.csv")

# %%
#Apply Sentiment

# %%
'''Understand WHY Sentiment?
Think like business:
👉 News says:
“Apple stock crashes” → Negative
“Apple beats expectations” → Positive
👉 Company wants:
“Can we predict stock movement from news?'''
news_df.columns

# %%
from textblob import TextBlob

def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

news_df["sentiment"] = news_df["clean_title"].apply(get_sentiment)

# %%
news_df.head()

# %%
news_df.columns

# %%
news_df = news_df[["title","clean_title", "time", "sentiment",]]

# %%
news_df.head()

# %%
print(news_df.columns)

# %%
#INSERT SENTIMENT INTO SQL

# %%
def sentiment_label(score):
    if score>0:
        return "Positive"
    elif score < 0:
        return "Negative"
    else:
        return "Neutral"

news_df["sentiment_label"] = news_df["sentiment"].apply(sentiment_label)

# %%
news_df.columns

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root",
    database="market_analysis"
)

cursor = conn.cursor()

for i, row in news_df.iterrows():
    cursor.execute(
        "INSERT INTO news (title, clean_title, sentiment, sentiment_label, time) VALUES (%s, %s, %s, %s, %s)",
        (row["title"], row["clean_title"], row["sentiment"], row["sentiment_label"], row["time"])
)

conn.commit()

# %%
print(news_df.columns)

# %%
for i, row in stock_df.iterrows():
    cursor.execute(
        "INSERT INTO stock_hourly (hour, avg_price) VALUES (%s, %s)",
        (row["hour"], row["avg_price"])
    )

conn.commit()

# %%
print(stock_df.columns)
